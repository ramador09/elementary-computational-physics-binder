# %%
# --- Setup: make the `ecp` support package available -----------------
# Colab opens a single notebook and installs nothing, so fetch `ecp` from
# the public repo if it isn't importable yet. On Binder/local it is already
# installed, so this cell is a fast no-op there.
try:
    import ecp  # noqa: F401
except ModuleNotFoundError:
    import subprocess, sys
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "-q",
         "git+https://github.com/ramador09/elementary-computational-physics-binder@main"],
        check=True,
    )

# %% [markdown]
# # 4.4 The Paradoxes, Computed
#
# <!-- This single H1 (one per notebook, "# <number> <Title>") is the page's
#      title: it sets the sidebar entry, breadcrumb, browser tab, and search
#      result. The branded banner below is generated by the shared `ecp`
#      package, so the look of every notebook in the series lives in one place. -->

# %%
from ecp.style import header, use_style

use_style()  # apply the series Matplotlib style
header(
    volume="Volume IV — Special Relativity",
    number="4.4",
    title="The Paradoxes, Computed",
    blurb="The twin paradox, the pole and the barn, and the relativistic "
    "Doppler effect: each apparent contradiction dissolves under honest "
    "computation — proper-time integrals along worldlines, and taking the "
    "relativity of simultaneity seriously.",
    difficulty="intermediate",
    estimate="120–150 min",
)

# %% [markdown]
# ## Notebook overview
#
# Special relativity has a reputation for paradox: twins who age differently, a pole that
# fits in a barn too short to hold it, clocks that each run slow in the other's frame. This
# notebook takes the three most famous of these and shows that none is a contradiction.
# Each is a clash between Newtonian intuition and the correct relativistic account, and each
# dissolves the moment we stop arguing in words and instead *compute* — either the proper
# time along the actual worldlines, or the consequences of taking the relativity of
# simultaneity seriously. There is no new physics here, only the careful application of
# [§4.1](crisis-and-postulates.ipynb)–[§4.3](spacetime-minkowski.ipynb).
#
# Two tools do all the work. The first is the **proper time** $\tau=\int\sqrt{1-\beta(t)^2}
# \,dt$, the time a clock actually reads as it travels its worldline, which we met
# geometrically in [§4.3](spacetime-minkowski.ipynb) and now evaluate as a genuine integral. Its central, counter-Euclidean
# property is that the *inertial* (straight) worldline between two events has the *longest*
# proper time, so the twin who accelerates ages less. The second tool is the **relativity of
# simultaneity** of [§4.1](crisis-and-postulates.ipynb): "the pole is fully inside with both doors shut at once" is a
# statement about simultaneity, and simultaneity is frame-dependent, so the two frames simply
# disagree about it without contradicting each other.
#
# We compute the twin paradox twice, once with an idealized instant turnaround and once with
# an honest smoothly-accelerated profile integrated two independent ways, and animate the two
# clocks drifting apart. We resolve the pole and barn in both frames and read the resolution
# off a Minkowski diagram. We close with the relativistic Doppler effect, including the purely
# relativistic transverse shift that has no classical analog and is a clean experimental test
# of time dilation.
#
# Times are quoted in years or nanoseconds as stated; $\beta=v/c$ is dimensionless, with
# $c=1/\sqrt{\mu_0\varepsilon_0}=2.998\times10^8\,$m/s where a length enters. The still worldline
# figures use the `ecp.draw` spacetime-diagram primitive built in [§4.3](spacetime-minkowski.ipynb). One effect, the twins'
# clocks developing in time, is genuine motion and is animated; the rest are clean stills.
#
# > **How to read the checks.** Each exercise closes with a `validate` call against an
# > independent fact: the travelling twin's $T/\gamma$; the proper-time integral agreeing
# > across `np.trapezoid` and `scipy.integrate.quad`; the inertial worldline being the
# > longest; each frame seeing the *other* object contracted; the door-closings offset by
# > $\gamma vL/c^2$; the Doppler shifts. A ✓ is strong evidence; a ✗ is a prompt to *locate
# > the discrepancy*, not a verdict.
# >
# > **Scope.** The kinematic paradoxes and the Doppler effect; relativistic *dynamics*
# > (four-momentum, $E=mc^2$) is [§4.5](four-momentum-energy.ipynb). See Taylor & Wheeler, *Spacetime Physics*
# > {cite}`taylor_wheeler`; Nolting, *Theoretical Physics 4* {cite}`nolting4`; and
# > [§4.1](crisis-and-postulates.ipynb) (simultaneity), [§4.2](lorentz-transformation.ipynb) (the transformation), [§4.3](spacetime-minkowski.ipynb) (proper time and the diagram primitive).

# %% [markdown]
# ## Theory in brief
#
# ### Why "paradoxes" are not contradictions
#
# Every special-relativity paradox is a clash between Newtonian intuition and the correct
# relativistic account, and every one resolves with a tool already in hand,
#
# ```{math}
# :label: eq-no-paradox
# \text{resolution} = \text{proper time along the worldline (4.3)} \ \text{ or } \ \text{relativity of simultaneity (4.1)} .
# ```
#
# We settle each by computation, not rhetoric.
#
# ### Proper time along a worldline
#
# The time a clock reads is the **proper time**, the "length" of its worldline in the
# spacetime metric,
#
# ```{math}
# :label: eq-proper-time
# \tau=\int d\tau=\int\sqrt{1-\frac{v(t)^2}{c^2}}\,dt=\int\frac{dt}{\gamma(t)} .
# ```
#
# Because of the minus sign in the metric, the **inertial (straight) worldline between two
# events has the maximum proper time**, the exact reverse of the Euclidean rule that a
# straight line is the shortest path. This single fact resolves the twin paradox.
#
# ### The twin paradox
#
# One twin travels out and back at high speed while the other stays home,
#
# ```{math}
# :label: eq-twin
# \tau_{\rm travel}=\int\sqrt{1-\beta(t)^2}\,dt < \tau_{\rm home}=T .
# ```
#
# The apparent symmetry — "each sees the other's clock run slow" — is false, because the
# worldlines are not symmetric: the traveller *accelerates* to turn around, and the
# stay-home twin does not. Integrating proper time along each worldline settles it with no
# ambiguity. We do both the idealized instant turnaround and an honest smooth acceleration.
#
# ### The pole-barn (ladder) paradox
#
# A pole of proper length $L_p$ longer than a barn of proper length $L_b$ "fits" inside when
# it runs through fast, length-contracted, in the barn frame; but in the pole's frame the
# *barn* is contracted and the pole cannot fit,
#
# ```{math}
# :label: eq-pole-barn
# \text{barn frame: } L_p/\gamma < L_b, \qquad \text{pole frame: } L_p > L_b/\gamma .
# ```
#
# The resolution is that "the pole is fully inside with both doors shut simultaneously" is a
# statement about simultaneity. The two door-closing events are simultaneous in the barn
# frame but separated by $\Delta t'=\gamma vL_b/c^2$ in the pole frame, so the two frames
# disagree about "at once" without disagreeing about anything physical.
#
# ### The relativistic Doppler effect
#
# Not a paradox but a real, measurable consequence, combining the classical Doppler geometry
# with time dilation,
#
# ```{math}
# :label: eq-doppler
# \frac{f_{\rm obs}}{f_{\rm src}}=\sqrt{\frac{1\pm\beta}{1\mp\beta}} \ \text{(approach/recession)}, \qquad \frac{f_{\rm obs}}{f_{\rm src}}=\frac{1}{\gamma} \ \text{(transverse)} .
# ```
#
# The transverse shift is a pure redshift even at $90^\circ$, from time dilation alone, with
# no classical analog — the Ives–Stilwell confirmation of time dilation.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.integrate import quad

from ecp import draw, validate
from ecp.animate import show

from scipy.constants import mu_0 as MU0  # vacuum permeability, T·m/A
from scipy.constants import epsilon_0 as EPS0  # vacuum permittivity, F/m

C_LIGHT = 1.0 / np.sqrt(MU0 * EPS0)  # speed of light, m/s
ACCENT, INK, SOFT = draw.ACCENT, draw.INK, draw.SOFT


def gamma(beta):
    """The Lorentz factor γ = 1/sqrt(1 − β^2) as a function of β = v/c (eq-proper-time).

    Parameters
    ----------
    beta : float or numpy.ndarray
        Speed as a fraction of c (|β| < 1).

    Returns
    -------
    float or numpy.ndarray
        The Lorentz factor, matching the shape of ``beta``.
    """
    return 1.0 / np.sqrt(1.0 - np.asarray(beta) ** 2)


def proper_time(beta_of_t, t0, t1, n=2001):
    """The proper time along a worldline: the integral of sqrt(1 − β(t)^2) dt (eq-proper-time).

    Evaluates the elapsed clock time for a worldline with instantaneous speed
    β(t) = v(t)/c, by the trapezoidal rule (``np.trapezoid``) over a dense
    grid of ``n`` samples. Direction does not matter, only speed, since the
    integrand depends on β^2.

    Parameters
    ----------
    beta_of_t : callable
        Function returning the speed β(t) (a fraction of c) at time ``t``.
    t0, t1 : float
        Start and end coordinate times (any consistent unit; the result shares it).
    n : int, optional
        Number of grid samples (default ``2001``).

    Returns
    -------
    float
        The proper time elapsed between ``t0`` and ``t1``.
    """
    t = np.linspace(t0, t1, n)
    integrand = np.sqrt(1.0 - beta_of_t(t) ** 2)
    return float(np.trapezoid(integrand, t))

# %% [markdown]
# ## Exercise 1 — The twin paradox, idealized
#
# One twin boards a rocket, flies out at $v=0.8c$, turns around, and returns; the other stays
# on Earth. On the Minkowski diagram their worldlines are plainly different: the stay-home
# twin is a straight vertical line, the traveller's is bent at the turnaround
# ({numref}`fig-tw-idealized`). The apparent symmetry that powers the "paradox" — each twin
# sees the other's clock run slow — is broken by that bend: only the traveller accelerates.
# In the idealized version the turnaround is instantaneous, so each leg is uniform motion and
# the traveller's proper time is simply $T/\gamma$ {eq}`eq-twin`.
#
# **This exercise (worked).** For a round-trip coordinate time $T=10\,$yr at
# $v=0.8c$, compute the traveller's proper time two ways — as $T/\gamma(0.8)$
# with the `gamma` helper, and as the worldline integral
# $\int\sqrt{1-\beta^2}\,dt$ with the `proper_time` helper (a constant-speed
# profile) — confirm they agree, and compare to the stay-home twin's $T$. The
# traveller returns younger, by a definite, computable amount.

# %%
# (solution hidden on the public site)

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 1

# %%
validate.close(
    tau_traveler,
    tau_integral,
    "T/γ agrees with the worldline proper-time integral — the traveller ages less",
    rtol=1e-9,
)
validate.check(
    tau_traveler < tau_home,
    "the travelling twin returns younger than the stay-home twin",
)

# %% [markdown]
# ## Exercise 2 — The twin paradox, honestly: smooth acceleration
#
# The instant turnaround is a fiction — a real rocket accelerates smoothly — so let us do the
# honest computation and integrate the proper time along a *smooth* worldline. Take the speed
# profile $\beta(t)=0.8\,|\sin(\pi t/T)|$, which starts and ends at rest and reverses
# direction at the midpoint turnaround {eq}`eq-proper-time`. The proper time is then the
# integral $\tau=\int_0^T\sqrt{1-\beta(t)^2}\,dt$, with no shortcut, and it depends only on
# the speed, not the direction. The point worth stressing is that the resolution of the
# paradox is *not* rhetoric: it is a number, obtained by integrating along the worldline.
#
# **This exercise (worked).** Compute $\tau$ two independent ways, with `np.trapezoid` over a
# dense `numpy` grid (the `proper_time` helper) and with `scipy.integrate.quad`, and confirm
# they agree (about $8.13\,$yr) and that $\tau<T$. The animation shows the two clocks ticking
# as the worldlines develop, the traveller's visibly falling behind.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 2

# %%
validate.close(
    tau_trapezoid,
    tau_quad,
    "the proper-time integral by np.trapezoid and scipy.integrate.quad agree",
    rtol=1e-3,
)
validate.check(
    tau_trapezoid < T,
    "the accelerated twin's proper time is less than the stay-home twin's",
)

# %%
# (solution hidden on the public site)

# %% [markdown]
# ## Exercise 3 — Why the inertial worldline is longest
#
# Behind the twin paradox is the geometric heart of the whole subject. Between two fixed
# events, *many* worldlines are possible, and they do not all carry the same proper time. The
# **inertial** (straight, constant-velocity) worldline carries the *most*, and every bent
# detour carries less {eq}`eq-proper-time`. This is the exact opposite of Euclidean geometry,
# where the straight line is the *shortest* distance between two points; the minus sign in
# the spacetime metric flips "shortest" to "longest" ({numref}`fig-tw-paths`).
#
# **This exercise (worked).** Between the same start and reunion events, compute the proper
# time of the straight worldline (the twin who never moves) and of several bent worldlines
# that go out to different turnaround distances and back, each via the `proper_time` integral,
# and confirm with a `numpy` comparison that the straight one is the maximum.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 3

# %%
validate.check(
    np.argmax(taus) == 0 and np.all(taus[1:] < taus[0]),
    "the inertial (straight) worldline maximizes proper time",
)

# %%
# (solution hidden on the public site)

# %% [markdown]
# ## Exercise 4 — The pole-barn paradox, both frames
#
# Now the second classic. A pole of proper length $L_p=10\,$m is carried at $v=0.8c$ toward a
# barn of proper length $L_b=8\,$m with doors at both ends. In the **barn's** frame the pole
# is length-contracted to $L_p/\gamma=6\,$m, comfortably shorter than the $8\,$m barn, so for
# an instant it is fully inside and both doors can shut. But in the **pole's** frame it is the
# *barn* that is contracted, to $L_b/\gamma=4.8\,$m, far too short to contain the $10\,$m pole
# {eq}`eq-pole-barn`. Both analyses are correct, which is exactly the apparent contradiction.
#
# **This exercise (worked).** Compute the contracted pole in the barn frame and the contracted
# barn in the pole frame, each as the proper length divided by `gamma(0.8)`, and confirm they
# are $6\,$m and $4.8\,$m. Each frame sees the *other* object contracted; the next exercise
# resolves the clash.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 4

# %%
validate.close(
    np.array([pole_in_barn, barn_in_pole]),
    np.array([6.0, 4.8]),
    "each frame sees the OTHER object contracted (pole→6 m, barn→4.8 m)",
    rtol=1e-3,
)

# %% [markdown]
# ## Exercise 5 — Pole-barn resolved by simultaneity
#
# The resolution is the relativity of simultaneity {eq}`eq-no-paradox`. "The pole is fully
# inside with both doors shut *at the same time*" is a claim about simultaneity, and
# simultaneity is frame-dependent. In the barn frame the two doors shut simultaneously, with
# the pole momentarily enclosed; but transforming those two events to the pole frame, they are
# separated by $\Delta t'=\gamma vL_b/c^2$ {eq}`eq-pole-barn`. In the pole frame the far door
# shuts and reopens *before* the near door shuts, so the pole is never enclosed and never in
# danger ({numref}`fig-pb-simultaneity`). Both frames agree on every physical fact — no door
# ever strikes the pole — and disagree only about the word "simultaneous".
#
# **This exercise (worked).** Transform the two door-closing events themselves
# — $(t{=}0,\ x{=}\mp L_b/2)$ in the barn frame — to the pole frame with the
# Lorentz transformation $t'=\gamma(t-vx/c^2)$, difference the mapped times,
# and confirm the offset equals the closed form $\gamma vL_b/c^2\approx35.6\,$ns.
# The events simultaneous in the barn frame are a definite $35.6\,$ns apart in
# the pole frame.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 5

# %%
validate.close(
    dt_pole_frame,
    gamma(beta_pb) * v_si * Lb / C_LIGHT**2,
    "transforming the door events gives the simultaneity offset Δt'=γvL_b/c²",
    rtol=1e-9,
)

# %%
# (solution hidden on the public site)

# %% [markdown]
# ## Exercise 6 — The relativistic Doppler effect
#
# The Doppler effect is not a paradox but a real, observable consequence, and relativity
# modifies the familiar classical version by folding in time dilation. A source approaching at
# $\beta$ is blueshifted and one receding is redshifted, by $f_{\rm obs}/f_{\rm src}=
# \sqrt{(1\pm\beta)/(1\mp\beta)}$ {eq}`eq-doppler`. The shift grows without bound as $\beta\to
# 1$ — light from a source rushing toward us at near-$c$ piles up enormously
# ({numref}`fig-dop`). This is the effect behind the cosmological redshift, by which the
# recession of distant galaxies stretches their light toward the red.
#
# **This exercise (worked).** *Derive* the shift kinematically rather than
# quoting it: an approaching source emits ticks at proper intervals $d\tau$;
# in our frame the emissions are $\gamma\,d\tau$ apart in time and each
# successive pulse starts $v\gamma\,d\tau$ closer, so simulate the emission
# events, add each pulse's light-travel time, and measure the arrival spacing.
# Confirm the measured $f_{\rm obs}/f_{\rm src}$ at $\beta=0.5$ equals
# $\sqrt{(1+\beta)/(1-\beta)}=\sqrt3\approx1.73$ (and its reciprocal for
# recession), and plot both branches against $\beta$.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 6

# %%
validate.close(
    doppler_approach,
    np.sqrt((1.0 + beta_d) / (1.0 - beta_d)),
    "the pulse-arrival simulation reproduces the approach shift √((1+β)/(1−β))",
    rtol=1e-9,
)
validate.close(
    doppler_recede,
    np.sqrt((1.0 - beta_d) / (1.0 + beta_d)),
    "and the recession shift √((1−β)/(1+β)) — Doppler derived, not quoted",
    rtol=1e-9,
)

# %%
# (solution hidden on the public site)

# %% [markdown]
# ## Exercise 7 — The transverse Doppler effect
#
# Here is the cleanest signature of time dilation in all of optics. Classically, a source
# moving *across* the line of sight — at the instant it is exactly abeam, $90^\circ$ — produces
# no Doppler shift, because it is neither approaching nor receding. Relativistically, there is
# still a shift: a pure **redshift** by $1/\gamma$, coming from time dilation alone, with no
# classical analog whatsoever {eq}`eq-doppler`. The moving source's clock simply runs slow, so
# every frequency it emits arrives lowered. This transverse Doppler shift, measured by Ives and
# Stilwell in 1938, is a direct experimental confirmation of time dilation.
#
# **This exercise (student).** At $90°$ there is no radial motion, so the shift
# is time dilation and nothing else: over one unit of our coordinate time the
# moving source's clock advances by the proper-time integral
# $\int\sqrt{1-\beta^2}\,dt$, which *is* the frequency ratio. Compute it with
# the `proper_time` helper at $\beta=0.5$, confirm it equals $1/\gamma\approx
# 0.866$, and note that it is a redshift ($<1$) at an angle where the classical
# effect vanishes.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 7

# %%
validate.close(
    f_transverse,
    1.0 / gamma(beta_d),
    "the proper-time integral gives the transverse shift 1/γ — pure time dilation",
    rtol=1e-9,
)

# %% [markdown]
# ## Exercise 8 — No paradoxes, only careful bookkeeping
#
# Step back over the three puzzles. The twin "paradox" was a failure to notice that the
# worldlines are not symmetric, repaired by integrating proper time along each. The pole-barn
# "paradox" was a failure to notice that "simultaneously" means different things in different
# frames, repaired by transforming the two door events. The Doppler effect was never a paradox
# at all, just a consequence we had not yet computed. In every case the appearance of
# contradiction came from applying part of relativity while forgetting the rest. Special
# relativity is strange, but it is entirely self-consistent: the universe keeps no
# contradictory books, and we need only read them in the right frame.
#
# **This exercise.** Close with the unifying check: confirm with one chained comparison
# `tau_ideal < tau_smooth < T` that the travelling twin's *smoothly-accelerated* proper time
# (Exercise 2) is both less than the stay-home time *and* greater than the idealized
# instant-turnaround value (Exercise 1), because a clock that spends less of the trip at top
# speed is dilated less — a quantitative, frame-independent statement with no trace of paradox.

# %%
# (solution hidden on the public site)

# %% [markdown]
# ### Validation 8

# %%
validate.check(
    ordered,
    "the smooth-acceleration proper time sits between the idealized value and the stay-home time",
)

# %% [markdown]
# ## Notebook summary
#
# - **The twin paradox** {eq}`eq-twin`, {eq}`eq-proper-time`: the worldlines are asymmetric
#   (only the traveller accelerates). Idealized, the traveller ages $T/\gamma=6\,$yr against
#   $10\,$yr; with a smooth profile $\beta(t)=0.8|\sin(\pi t/T)|$ the proper-time integral is
#   $\approx8.13\,$yr by both `np.trapezoid` and `scipy.integrate.quad`, still less than $T$.
# - **The inertial worldline is longest** {eq}`eq-proper-time`: among paths between the same
#   two events the straight one carries the maximum proper time, the reverse of the Euclidean
#   rule — the geometric root of the twin result.
# - **The pole-barn paradox** {eq}`eq-pole-barn`: each frame sees the *other* contracted (pole
#   $\to6\,$m in the barn frame, barn $\to4.8\,$m in the pole frame). It dissolves by
#   simultaneity {eq}`eq-no-paradox`: the door-closings simultaneous in the barn frame are
#   $\Delta t'=\gamma vL_b/c^2\approx35.6\,$ns apart in the pole frame, so "fully enclosed" is
#   frame-dependent and nothing physical is contradicted.
# - **The relativistic Doppler effect** {eq}`eq-doppler`: $\sqrt{(1\pm\beta)/(1\mp\beta)}$ gives
#   blueshift $\sqrt3$ and redshift $1/\sqrt3$ at $\beta=0.5$; the **transverse** shift $1/\gamma
#   \approx0.866$ is a pure redshift from time dilation, with no classical analog (Ives–Stilwell).
# - **The lesson**: every "paradox" was a bookkeeping slip — integrate proper time along the
#   actual worldline, and remember that simultaneity is relative.

# %% [markdown]
# ## Outlook
#
# - **Relativistic dynamics ([§4.5](four-momentum-energy.ipynb)).** Four-momentum, $E=mc^2$, and relativistic collisions,
#   where the kinematics of [§4.1](crisis-and-postulates.ipynb)–§4.4 gains a dynamics.
# - **The experimental record.** Muon lifetimes (time dilation), Ives–Stilwell (the transverse
#   Doppler computed here), and GPS clock corrections — a pointer to the SR+GR combination.
# - **Accelerated observers in depth ([§4.8](gr-capstone.ipynb)).** The turnaround twin generalises to the
#   equivalence principle and the bridge to general relativity.
# - **Cross-reference** [§4.1](crisis-and-postulates.ipynb) (simultaneity), [§4.2](lorentz-transformation.ipynb) (the transformation), and [§4.3](spacetime-minkowski.ipynb) (proper time and
#   the spacetime-diagram primitive used throughout this notebook).

# %%
from ecp.style import footer

footer()
